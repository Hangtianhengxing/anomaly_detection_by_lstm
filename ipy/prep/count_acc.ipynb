# %%
day = "20170422"
total_cnt = 0

print("日付: {}".format(day))
for time_idx in range(9, 17):
    data_df = pd.read_csv("../../data/datasets/{}/default/time_series_{}.csv".format(day, time_idx))
    print("{}時: {}回".format(time_idx, np.sum(data_df["label"])))
    total_cnt += np.sum(data_df["label"])
    
print("合計: {}".format(total_cnt))
# Out:
# 日付: 20170422
# 9時: 18回
# 10時: 18回
# 11時: 12回
# 12時: 14回
# 13時: 5回
# 14時: 0回
# 15時: 13回
# 16時: 4回
# 合計: 84

# %% [raw]
# 日付: 20170416(日)
# 9時: 19回
# 10時: 13回
# 11時: 14回
# 12時: 7回
# 13時: 3回
# 14時: 0回
# 15時: 0回
# 16時: 6回
# 合計: 62
#
# 日付: 20170417(月)
# 9時: 19回
# 10時: 14回
# 11時: 17回
# 12時: 14回
# 13時: 2回
# 14時: 0回
# 15時: 0回
# 16時: 12回
# 合計: 78
#
# 日付: 20170418(火)
# 9時: 15回
# 10時: 22回
# 11時: 17回
# 12時: 11回
# 13時: 2回
# 14時: 0回
# 15時: 0回
# 16時: 7回
# 合計: 74
#
# 日付: 20170420(木)
# 9時: 21回
# 10時: 9回
# 11時: 9回
# 12時: 11回
# 13時: 1回
# 14時: 0回
# 15時: 0回
# 16時: 14回
# 合計: 65
#
# 日付: 20170421(金)
# 9時: 4回
# 10時: 7回
# 11時: 6回
# 12時: 17回
# 13時: 2回
# 14時: 0回
# 15時: 0回
# 16時: 2回
# 合計: 38
#
# 日付: 20170422(土)
# 9時: 18回
# 10時: 18回
# 11時: 12回
# 12時: 14回
# 13時: 5回
# 14時: 0回
# 15時: 13回
# 16時: 4回
# 合計: 84
#
# 日付: 20181030(火)
# 9時: 30回
# 10時: 20回
# 11時: 31回
# 12時: 34回
# 13時: 19回
# 14時: 5回
# 15時: 6回
# 16時: 8回
# 合計: 153
#
# 日付: 20181031(水)　(餌なし)
# 9時: 25回
# 10時: 21回
# 11時: 31回
# 12時: 27回
# 13時: 22回
# 14時: 9回
# 15時: 14回
# 16時: 10回
# 合計: 159
